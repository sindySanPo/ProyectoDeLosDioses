# %%
#hola caras de carambola
#aquí inicia el proyecto

# %%
import pandas as pd
import xlwings as xl
from PyQt5.QtWidgets import *
import sys

# %%
class FileBotton(QWidget):
    def __init__(self, name = 'FilesBottons'):
        super(FileBotton,self).__init__()
        self.setWindowTitle(name)
        self.resize(400,150)   # set the pop up widget's size
        # btn3
        self.btn_chooseFile3 = QPushButton(self)  
        self.btn_chooseFile3.setObjectName("btn_chooseFile")  
        self.btn_chooseFile3.setText("[---BOM Report---]")
        
        # set the widget's layout
        layout = QVBoxLayout()
        layout.addWidget(self.btn_chooseFile3)
        
        self.setLayout(layout)

        # set the widget's signal
        self.btn_chooseFile3.clicked.connect(self.slot_btn_chooseFile3)

    def slot_btn_chooseFile3(self):
        global filePath
        filePath, filetype = QFileDialog.getOpenFileName(self,  
                                    "Choose AMO OP Indy file's Path",  
                                    "", # start path
                                    "Excel File (*.xlsx *.xls *.xlsb);;All Files (*)")  

        if filePath != "":
            print(filePath)
            self.close()
        elif filePath == "":
            return 



def choose_file():
    app = QApplication(sys.argv)
    files = FileBotton('Select BOM Report')
    files.show()
    try:
        sys.exit(app.exec_())
    except SystemExit:
        print('Closing Window...')

choose_file()
# Out:
# C:/Users/sanchesi/Downloads/AV Readiness - BOM Report.xlsx
# Closing Window...

# %%
bomAvReport = pd.read_excel(filePath, sheet_name='Sheet1')
bomAvReport
# Out:
#                SKU  Site  BOM Level    Commodity        Part  \
# 0      671R3AA#ABY  0874          1  Other Items  746408-006
# 1      671R3AA#ABY  0874          2  Power Cords  213353-008
# 2      671R3AA#ABY  0874          1          NaN  N13006-001
# 3      671R3AA#ABY  0874          2          NaN  M52944-001
# 4      671R3AA#ABY  0874          2          NaN  M52944-003
# ...            ...   ...        ...          ...         ...
# 62693  671R3AA#ABU  0874          2          NaN  796026-A21
# 62694  671R3AA#ABU  0874          3          NaN  827645-A23
# 62695  671R3AA#ABU  0874          2          NaN  L71267-073
# 62696  671R3AA#ABU  0874          2          NaN  M73993-B21
# 62697  671R3AA#ABU  0874          3          NaN  M42771-B21
#
#                                     Description Make/Buy Material Type  \
# 0                 ASSY CORD PWR C5 1.0M BLK DEN     MAKE          HALB
# 1            CORD, PWR,AC LINE,C5-DENMARK,1.00m      BUY           ROH
# 2                      GNRC-65W USB C PD Taroko     MAKE          HALB
# 3             65W USB-C PD AC Adapter nPFC 3pin      BUY           ROH
# 4             65W USB-C PD AC Adapter nPFC 3pin      BUY           ROH
# ...                                         ...      ...           ...
# 62693  Kit, Phantom 1YR Print WW ACCY WARR-EMEA     MAKE          HALB
# 62694            1/0/0 Print ACCY Warranty-EMEA      BUY           ROH
# 62695                  Brown box, FLH 7AC37-073      BUY           ROH
# 62696  Kit, Product Notices Info Web Pointer-ML     MAKE          HALB
# 62697  RTF, Product Notices Info Web Pointer-ML      BUY           ROH
#
#       xCost Who Edited   xCost Update Date  ...  xCost Contract   Jun-22  \
# 0                  NaN                 NaN  ...          1.2900   1.2900
# 1                  CCS  05/02/2022 02:09AM  ...          1.2900   1.2900
# 2                  NaN                 NaN  ...         10.8000  10.8000
# 3                  CCS  01/29/2022 04:00AM  ...         10.8000  10.8000
# 4                  CCS  01/02/2022 07:25PM  ...          0.0000   0.0000
# ...                ...                 ...  ...             ...      ...
# 62693              NaN                 NaN  ...          0.0000   0.0000
# 62694              NaN                 NaN  ...          0.0000   0.0000
# 62695              CCS  04/01/2022 10:55AM  ...          0.3717   0.3717
# 62696              NaN                 NaN  ...          0.0184   0.0184
# 62697              CCS  04/22/2021 10:59AM  ...          0.0184   0.0184
#
#         Jul-22   Aug-22   Sep-22   Oct-22    Delta  Dent BOM  \
# 0       1.2900   1.2900   1.2900   1.2900   1.2900    dentro
# 1       1.2900   1.2900   1.2900   1.2900   0.0000     fuera
# 2      10.8000  10.8000  10.8000  10.8000  10.8000    dentro
# 3      10.8000  10.8000  10.8000  10.8000   0.8000     fuera
# 4       0.0000   0.0000   0.0000   0.0000   0.7000     fuera
# ...        ...      ...      ...      ...      ...       ...
# 62693   0.0000   0.0000   0.0000   0.0000   0.0000     fuera
# 62694   0.0000   0.0000   0.0000   0.0000   0.0000     fuera
# 62695   0.3717   0.3717   0.3717   0.3717   0.0000     fuera
# 62696   0.0184   0.0184   0.0184   0.0184   0.0184     fuera
# 62697   0.0184   0.0184   0.0184   0.0184   0.0000     fuera
#
#        Repite/reemplazo  Unnamed: 22
# 0                    no          1.0
# 1                    no          1.0
# 2                    no          1.0
# 3                    si          1.0
# 4                    si          0.0
# ...                 ...          ...
# 62693                no          1.0
# 62694                no          1.0
# 62695                no          1.0
# 62696                no          1.0
# 62697                si          1.0
#
# [62698 rows x 23 columns]
